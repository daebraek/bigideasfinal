# %%
import pandas as pd

# %%
trash = pd.read_csv("smart-trash/trash.csv")

# %%
trash.head(10)
# Out:
#       _id  container_id  receptacle_model_id      assignment_date  \
# 0  411907             1                   74  2017-09-14T13:24:40
# 1  411908             2                   74  2017-09-14T13:24:40
# 2  411909             3                   74  2017-09-14T13:24:40
# 3  411910             4                   74  2017-09-14T13:24:40
# 4  411911             5                   74  2017-09-19T12:22:45
# 5  411912             6                   74  2017-09-19T12:22:46
# 6  411913             7                   74  2017-09-19T12:22:46
# 7  411914             8                   74  2017-09-19T12:22:46
# 8  411915             9                   74  2017-09-19T12:22:46
# 9  411916            10                   74  2017-09-19T12:22:46
#
#      last_updated_date    group_name           address        city  \
# 0  2022-11-24T13:17:19  1st Division   122 E North Ave  Pittsburgh
# 1  2022-12-31T01:54:25  1st Division  2507 Brighton Rd  Pittsburgh
# ...

# %%
unique = trash["neighborhood"].unique()
unique
# Out:
# array(['Central Northside', 'Marshall-Shadeland', 'Allegheny Center',
#        'California-Kirkbride', 'Manchester', 'Perry North', 'Perry South',
#        'Fineview', 'Allegheny West', 'Troy Hill', 'East Allegheny',
#        'Brighton Heights', 'Spring Hill-City View', 'Spring Garden',
#        'Northview Heights', 'Chateau', 'Bluff', 'Garfield', 'Arlington',
#        'Greenfield', 'East Liberty', 'Morningside', 'Mt. Oliver',
#        'Carrick', 'Beechview', 'Point Breeze',
#        'Central Business District', 'Shadyside', 'Bloomfield',
#        'Brookline', 'South Oakland', 'Highland Park', 'South Side Flats',
#        'Allentown', 'South Side Slopes', 'West End', 'Knoxville',
#        'Beltzhoover', 'Central Oakland', 'Larimer', 'South Shore',
#        'Mount Washington', 'Sheraden', 'Crafton Heights', 'Elliott',
#        'Westwood', 'Windgap', 'East Carnegie', 'Crawford-Roberts',
#        'North Shore', 'Strip District', 'Upper Hill', 'Polish Hill',
# ...

# %%
trash['neighborhood'].value_counts().head(5)
# Out:
# neighborhood
# Shadyside              76
# East Liberty           68
# Squirrel Hill South    63
# Bloomfield             58
# North Shore            53
# Name: count, dtype: int64
